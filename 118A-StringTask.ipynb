# %% [markdown]
# ![image.png](attachment:image.png)

# %%
program = input()
vowels = "AOYEUIaoyeui"

for vowel in vowels:
    program = program.replace(vowel, "")
    
program = "."+".".join(program).lower()
        
print(program)
# Out:
# .c.d.f.r.c.s
