# %% [markdown]
# ![image.png](attachment:image.png)

# %%
username = input().lower().strip()
ans = len(set(username))

if ans%2 == 0:
    print("CHAT WITH HER!")
else:    
    print("IGNORE HIM!")
# Out:
# CHAT WITH HER!
