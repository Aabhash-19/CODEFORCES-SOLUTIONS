# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
p = list(map(int, input().split()))

# Create the inverse permutation
result = [0] * n
for i, gift_to in enumerate(p):
    result[gift_to-1] = i+1

print(' '.join(map(str, result)))
