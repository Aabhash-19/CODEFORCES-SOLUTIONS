# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
counts = 0
for _ in range(n):
    p, v, t = map(int, input().split())
    if p + v + t >= 2:
        count+=1
print(counts)
# Out:
# 3
