# %% [markdown]
# ![image.png](attachment:image.png)

# %%
string1 = input().lower()
string2 = input().lower()

if len(string1) == len(string2):
    if string1 > string2:
        print("1")
    elif string1 < string2:
        print("-1")
    elif string1 == string2:
        print("0")
else:
    raise ValueError
# Out:
# 0
