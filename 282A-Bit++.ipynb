# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
inputs = []

x = 0
for _ in range(n):
    user_inputs = input().strip()
    inputs.append(user_inputs)

    if user_inputs == "++X" or user_inputs == "X++":
        x+=1
    elif user_inputs == "--X" or user_inputs == "X--":
        x-=1  

print(x)
# Out:
# 0
