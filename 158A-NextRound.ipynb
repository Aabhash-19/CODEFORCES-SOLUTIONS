# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n, k= map(int, input().split())
numbers = list(map(int, input().split())) 
k = numbers[k-1]

count = 0
for i in numbers:
    if i >= k and i > 0:
        count+=1

print(count)
# Out:
# 1
