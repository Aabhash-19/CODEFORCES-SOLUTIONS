# %% [markdown]
# ![image.png](attachment:image.png)

# %%
p = input()

contains_H = "H" in p
contains_Q = "Q" in p
contains_9 = "9" in p

if contains_H or contains_Q or contains_9:
    print("YES")
else:
    print("NO")
# Out:
# NO
