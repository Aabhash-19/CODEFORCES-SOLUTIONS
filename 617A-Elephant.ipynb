# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = int(input())
if x==1 or x==2 or x==3 or x==4 or x==5:
    print(1)
elif x > 5 and x % 5 == 0:
    print(x//5)    
elif x > 5 and x % 5 != 0:
    print(x//5 + 1)
# Out:
# 3
