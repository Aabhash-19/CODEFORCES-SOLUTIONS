# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = input()
upper = []
lower = []

for letter in s:
    if letter.isupper():
        upper.append(letter)

    elif letter.islower():
        lower.append(letter) 

if len(upper) > len(lower):
    print(s.upper())

elif len(lower) >= len(upper):
    print(s.lower())
# Out:
# matrix
