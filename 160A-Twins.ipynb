# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
coins_deno = list(map(int, input().split()))
coins_deno.sort()
total = sum(coins_deno)

count = 0
current_sum = 0

for i in range(n-1,-1,-1):
    current_sum+=coins_deno[i]
    count+=1

    if current_sum > total/2:
        break

print(count)
# Out:
# 2
