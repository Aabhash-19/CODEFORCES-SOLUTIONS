# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = int(input())
s = input().upper()

Anton = []
Danik = []

for i in s:
    if i == "A" :
        Anton.append(s)
    elif i == "D":
        Danik.append(s)    

if len(Anton) > len(Danik):
    print("Anton")
elif len(Dainik) > len(Anton):
    print("Danik")        
elif len(Anton) == len(Danik):
    print("Friendship")
# Out:
# Anton

# %%
n = int(input())
s = input().upper()

anton_count = s.count('A')
danik_count = s.count('D')

if anton_count > danik_count:
    print("Anton")
elif danik_count > anton_count:
    print("Danik")
else:
    print("Friendship")
# Out:
# Danik
