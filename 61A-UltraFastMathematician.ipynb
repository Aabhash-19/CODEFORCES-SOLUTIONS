# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m = input()
n = input()

result = []

for i in range(len(m)):
    if m[i] != n[i]:
        result.append('1')
    else:
        result.append('0')    

print(''.join(result))
# Out:
# 1110001
