# %% [markdown]
# ![image.png](attachment:image.png)

# %%
k, n, w = map(int, input().split())
bananas = (w * (w + 1))//2 ## AP
total_cost = k * bananas

if n >= total_cost:
    print(0)
else:
    print(total_cost - n)
# Out:
# 13
